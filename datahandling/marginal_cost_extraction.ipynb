# %% [markdown]
# # Marginal Cost Extraction from LCOE Excel File
# This notebook extracts relevant data from the provided Excel file, computes marginal costs, and interpolates for the years between available data points (e.g., 2020, 2030, 2050). Finally, it saves the extracted and interpolated data into a CSV file.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

# Load the Excel file
file_path = '../data/lcoe_calculator_with_ee_module_0.xlsm'

# Load the relevant sheets ('ResultsAllYears')
results_df = pd.read_excel(file_path, sheet_name='ResultsAllYears')

# Filter relevant technologies (thermal)
thermal_keywords = ['coal', 'gas', 'biomass', 'CHP', 'thermal']
thermal_df = results_df[results_df['Technology name'].str.contains('|'.join(thermal_keywords), case=False, na=False)]

# Select relevant columns (Technology name, Year, Fuel cost, O&M costs)
thermal_df = thermal_df[['Technology name', 'Year', 'Fuel cost', 'O&M costs']]

# Calculate Marginal Cost (Fuel cost + O&M costs)
thermal_df['Marginal Cost'] = thermal_df['Fuel cost'] + thermal_df['O&M costs']

thermal_df.head(50)
# Out:
#                                       Technology name  Year  Fuel cost  \
# 12  18 Me BP STR 80MW input, Straw CHP Medium, 2 d...  2015  36.299772
# 13  18 Me BP STR 80MW input, Straw CHP Medium, 2 d...  2020  37.896525
# 14  18 Me BP STR 80MW input, Straw CHP Medium, 2 d...  2030  40.614203
# 15  18 Me BP STR 80MW input, Straw CHP Medium, 2 d...  2050  40.625592
# 16  16 ME BP SC NGA - Gas Turbine Single Cycle, me...  2015  60.521160
# 17  16 ME BP SC NGA - Gas Turbine Single Cycle, me...  2020  63.275650
# 18  16 ME BP SC NGA - Gas Turbine Single Cycle, me...  2030  71.195960
# 19  16 ME BP SC NGA - Gas Turbine Single Cycle, me...  2050  70.049349
# 20  16La EX CC NGA CC large CHP Gas Turbine combin...  2015  48.359166
# 21  16La EX CC NGA CC large CHP Gas Turbine combin...  2020  51.690425
# 22  16La EX CC NGA CC large CHP Gas Turbine combin...  2030  57.251157
# 23  16La EX CC NGA CC large CHP Gas Turbine combin...  2050  56.585098
# 24                  17La_EX_COA CHP coal 400-700 MWwe  2015  18.746888
# 25                  17La_EX_COA CHP coal 400-700 MWwe  2020  19.574409
# 26                  17La_EX_COA CHP coal 400-700 MWwe  2030  20.014991
# 27                  17La_EX_COA CHP coal 400-700 MWwe  2050  17.702235
# 28                                       Coal FGD INT  2015  25.469269
# 29                                       Coal FGD INT  2020  27.373654
# 30                                       Coal FGD INT  2030  29.204789
# 31                                       Coal FGD INT  2050  26.030217
# 32                                    Coal no FGD INT  2015  25.469269
# 33                                    Coal no FGD INT  2020  27.373654
# 34                                    Coal no FGD INT  2030  29.204789
# 35                                    Coal no FGD INT  2050  26.030217
# 36                               Natural gas CCGT INT  2015  55.740794
# 37                               Natural gas CCGT INT  2020  60.701769
# 38                               Natural gas CCGT INT  2030  68.377322
# 39                               Natural gas CCGT INT  2050  63.829321
# 56                                  Biomass plant INT  2015  30.056039
# 57                                  Biomass plant INT  2020  30.056039
# 58                                  Biomass plant INT  2030  30.056039
# 59                                  Biomass plant INT  2050  30.797602
# 64  16 La EX LTE COA no_inv_exipla  - Coal CHP Lif...  2015  17.990029
# 65  16 La EX LTE COA no_inv_exipla  - Coal CHP Lif...  2020  19.440135
# 66  16 La EX LTE COA no_inv_exipla  - Coal CHP Lif...  2030  21.929368
# 67  16 La EX LTE COA no_inv_exipla  - Coal CHP Lif...  2050        NaN
# 68  16La REF_EX  WPE_COA_exibo_no_inv_exipla Woodp...  2015  72.518579
# 69  16La REF_EX  WPE_COA_exibo_no_inv_exipla Woodp...  2020  70.063687
# 70  16La REF_EX  WPE_COA_exibo_no_inv_exipla Woodp...  2030  69.851460
# 71  16La REF_EX  WPE_COA_exibo_no_inv_exipla Woodp...  2050        NaN
# 72  16La REF_EX  WCH_COA_Newboi_ no_inv_exipla Woo...  2015  49.731951
# 73  16La REF_EX  WCH_COA_Newboi_ no_inv_exipla Woo...  2020  49.108118
# 74  16La REF_EX  WCH_COA_Newboi_ no_inv_exipla Woo...  2030  50.623832
# 75  16La REF_EX  WCH_COA_Newboi_ no_inv_exipla Woo...  2050        NaN
# 76  16La REF_EX WCH_COA_exi_exibo_no_inv_exipla Wo...  2015  53.298142
# 77  16La REF_EX WCH_COA_exi_exibo_no_inv_exipla Wo...  2020  52.465656
# 78  16La REF_EX WCH_COA_exi_exibo_no_inv_exipla Wo...  2030  53.915529
# 79  16La REF_EX WCH_COA_exi_exibo_no_inv_exipla Wo...  2050        NaN
# 80  18La_EX_EXI_COA ex_inv_cost - Coal CHP existin...  2015        NaN
# 81  18La_EX_EXI_COA ex_inv_cost - Coal CHP existin...  2020  22.602753
#
#     O&M costs  Marginal Cost
# 12  42.481215      78.780987
# 13  42.401014      80.297539
# 14  40.010345      80.624548
# 15  36.032124      76.657716
# 16   9.135643      69.656804
# 17   8.920687      72.196337
# 18   8.512270      79.708230
# 19   8.168340      78.217689
# 20  11.448975      59.808140
# 21  11.168792      62.859217
# 22  10.595203      67.846360
# 23   9.965145      66.550243
# 24  10.983441      29.730329
# 25  10.699636      30.274045
# 26  10.329939      30.344931
# 27   9.904629      27.606865
# 28   8.912166      34.381435
# 29   8.767540      36.141194
# 30   8.585152      37.789941
# 31   8.231679      34.261896
# 32   7.575342      33.044610
# 33   7.452409      34.826063
# 34   7.297379      36.502168
# 35   6.996927      33.027144
# 36   7.423924      63.164718
# 37   7.244810      67.946578
# 38   6.912030      75.289352
# 39   6.655595      70.484915
# 56  22.393768      52.449806
# 57  21.866747      51.922785
# 58  21.385472      51.441510
# 59  19.629272      50.426874
# 64  11.721998      29.712027
# 65  11.295893      30.736028
# 66  10.849934      32.779302
# 67        NaN            NaN
# 68  13.025604      85.544183
# 69  12.544948      82.608635
# 70  12.040496      81.891956
# 71        NaN            NaN
# 72  14.817458      64.549409
# 73  14.266817      63.374935
# 74  13.691215      64.315047
# 75        NaN            NaN
# 76  17.212490      70.510632
# 77  16.564034      69.029690
# 78  15.883416      69.798946
# 79        NaN            NaN
# 80        NaN            NaN
# 81        NaN            NaN

# %%
# Pivot the table to get years as columns for easier interpolation
thermal_pivot = thermal_df.pivot_table(index='Technology name', columns='Year', values='Marginal Cost')

# Interpolate for missing years (2020-2050 range)
years = np.arange(2020, 2051)  # Create a range of years from 2020 to 2050
interpolated_df = pd.DataFrame(index=thermal_pivot.index)

# Interpolation function for each technology
for tech in thermal_pivot.index:
    tech_costs = thermal_pivot.loc[tech].dropna()  # Get non-null costs for this technology
    interp_func = interp1d(tech_costs.index, tech_costs.values, kind='linear', fill_value="extrapolate")
    interpolated_df[tech] = interp_func(years)

# Transpose to get years back as rows and technologies as columns
interpolated_df = interpolated_df.T
interpolated_df.columns = thermal_pivot.index

# Save the interpolated marginal costs to a CSV file
interpolated_df.to_csv('interpolated_marginal_costs.csv')

print("Interpolated data has been saved to 'interpolated_marginal_costs.csv'.")
